# %% [markdown]
# # 探索的データ分析

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import japanize_matplotlib

# %% [markdown]
# # データ前処理

# %%
# 訓練/テストデータの読込
train = pd.read_csv('../data/train.csv')
test  = pd.read_csv("../data/test.csv")

# %%
display(train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### データ内容の確認

# %%
# 基本統計量
display(train.describe())

# 欠損値やデータ型
display(train.info())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# ...

# %%
# Embarked のデータ分布
fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data=train, x="Embarked",hue="Embarked", ax=ax[0])
sns.barplot(data=train, x="Embarked", y="Survived", hue="Embarked",ax=ax[1])

ax[0].set_title("乗船港（Embarked）の分布")
ax[1].set_title("乗船港（Embarked）と生存の関係")
plt.show()

# %%
# Fare のデータ分布
fig, ax = plt.subplots(2, 2, figsize=(15,10))
sns.histplot(data=train, x="Fare", ax=ax[0][0], bins=30, kde=True)
sns.boxplot(data=train, y="Fare", ax=ax[0][1])
sns.boxplot(data=train, y="Fare", hue="Pclass", ax=ax[1][0])


ax[0][0].set_title("旅客運賃の分布")
ax[0][1].set_title("旅客運賃の箱ひげ図")
ax[0][1].set_xlabel("Fare")

plt.show()

# %%
# Age のデータ分布
fig, ax = plt.subplots(2, 2, figsize=(12,5))
sns.histplot(data=train, x="Age", ax=ax[0][0], bins=20, kde=True)
sns.boxplot(data=train, y="Age", ax=ax[0][1])
sns.kdeplot(data=train, x="Age", fill=True, hue="Survived", ax=ax[1][0])

ax[0][0].set_title("旅客運賃の分布")
ax[0][1].set_title("旅客運賃の箱ひげ図")
ax[0][1].set_xlabel("Fare")

plt.show()

# %%
# pclass のデータ分布
fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data=train, x="Pclass", hue="Pclass", ax=ax[0])
sns.barplot(data=train, x="Pclass", y="Survived", hue="Pclass", ax=ax[1])

ax[0].set_title("旅客運賃の分布")
ax[1].set_title("旅客運賃の箱ひげ図")
ax[1].set_xlabel("Fare")

plt.show()

# %%
# Sex のデータ分布
fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data=train, x="Sex", hue="Sex", ax=ax[0])
sns.barplot(data=train, x="Sex", y="Survived", hue="Sex", ax=ax[1])

ax[0].set_title("旅客運賃の分布")
ax[1].set_title("旅客運賃の箱ひげ図")
ax[1].set_xlabel("Fare")

plt.show()
